# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehasrinekkalapudi/BASIC-ML/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Question 1
# ## **Basic Line Plot**
# ### Plot a simple line graph of 𝑦 = 𝑥2 for 𝑥 values ranging from -10 to 10.
# ###Label the x-axis as "X Values" and the y-axis as "Squared Values."
# ###Add a title to the graph.

# %%
x=range(-10,11)
y=[i**2 for i in x]
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Basic Line Plot")
plt.show()

# %% [markdown]
# #Question 2
# ##**Bar Plot**
# ###Create a bar chart showing the marks scored by 5 students: ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].
# ###Add labels to the x-axis and y-axis and give the chart a title.

# %%
stu=['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
marks=[85, 90, 78, 92, 88]
plt.bar(stu,marks)
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# #Question 3
# ##**Scatter Plot**
# ###Generate two lists of 20 random integers each (for x and y coordinates).
# ###Create a scatter plot with these values, and customize it by adding color, size, and labels to the points.

# %%
import numpy as np
x=[random.randint(1, 21) for _ in range(20)]
y=[random.randint(1, 21) for _ in range(20)]
plt.scatter(x, y, color='green', s=100, label='Points')
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# #Question 4
# ##***Histogram***
# ###Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram.
# ### Customize the number of bins and add a grid to the plot.

# %%
data=np.random.randn(100)
plt.hist(data,bins=20,color='green',edgecolor='red')
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.grid(True)
plt.show()

# %% [markdown]
# #Question 5
# ##**Pie Chart**
# ###Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E'] with values [20, 30, 25, 15, 10].
# ###Display the percentage values on the chart and use a color palette for differentiation.

# %%
c=['A', 'B', 'C', 'D', 'E']
v=[20, 30, 25, 15, 10]
plt.pie(
    v,
    labels=c,
    autopct='%1.0f%%',
    colors=['red', 'green', 'blue', 'yellow', 'orange']
)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# #Question 6
# ##**Box Plot (Seaborn)**
# ###Create a box plot to visualize the distribution of the marks scored by students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].
# ###Highlight the median and any outliers.

# %%
import seaborn as sns
marks=[78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
sns.boxplot(marks)
plt.title("Box Plot")
plt.xlabel("Marks")
plt.ylabel("Students")
plt.show()

# %% [markdown]
# #Question 7
# ##**Heatmap (Seaborn)**
# ###Create a 5x5 matrix with random integers between 1 and 10 using np.random.randint() and visualize it as a heatmap using Seaborn.
# ###Add a color bar and annotate the heatmap with the values.

# %%
matrix=np.random.randint(1,11,size=(5,5))
sns.heatmap(matrix,annot=True,cmap='YlGnBu',cbar=True)
plt.title("Heatmap")
plt.show()

# %% [markdown]
# #Question 8
# ## **Comparison of Matplotlib and Seaborn**
# ###Generate a pair of plots (bar charts or line plots) using the same data in both Matplotlib and Seaborn.
# ###Highlight the differences in the code, syntax, and aesthetics of the two libraries.

# %% [markdown]
# ####Matplotlib tends to have more basic look,requiring additional styling for polished look where as Seaborn comes with better default aesthetics and automatically styles

# %%
#Matplotlib
c=['A', 'B', 'C', 'D', 'E']
v=[20, 30, 25, 15, 10]
plt.bar(c,v,color='green')
plt.title("Bar Plot using Matplotlib")
plt.show()
#Seaborn
sns.barplot(x=c,y=v,color='green')
plt.title("Bar Plot using Seaborn")
plt.show()

# %% [markdown]
# #Question 9
# ##**Pair Plot (Seaborn)**
# ###Manually create a small dataset with columns such as 'Age', 'Height', 'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
import pandas as pd
data={
    'Age':[20,25,30,35,40,45,50,55,60,65],
    'Height':[160,169,172,175,180,182,196,198,204,207],
    'Weight':[60,69,72,75,80,82,96,98,104,107]
}
df=pd.DataFrame(data)
sns.pairplot(df)
plt.show()

# %% [markdown]
# #Question 10
# ##**Save and Style plots**
# ###Plot any graph of your choice and save it in both .png and .pdf formats.
# ###Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain how the style impacts the visualization.

# %% [markdown]
# #####Grammar of graphics(ggplot) has visualizations look publication ready right out of the box, where as matplotlib has somewhat utilitarian appearance.

# %%
x=range(-10,11)
y=[i**2 for i in x]
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Basic Line Plot")
plt.savefig('plot.png')
plt.savefig('plot.pdf')
plt.show()
#applying built-in style
plt.style.use('ggplot')
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Basic Line Plot")
plt.savefig('plot.png')
plt.savefig('plot.pdf')
plt.show()
